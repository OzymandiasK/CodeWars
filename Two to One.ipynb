# %% [markdown]
# # Two to One - Codewars - Python

# %% [markdown]
# Take 2 strings s1 and s2 including only letters from ato z.
#
# Return a new sorted string, the longest possible, containing distinct letters - each taken only once - coming from s1 or s2.
#
# Examples:
#
# a = "xyaabbbccccdefww"
# b = "xxxxyyyyabklmopq"
# longest(a, b) -> "abcdefklmopqwxy"
#
# a = "abcdefghijklmnopqrstuvwxyz"
# longest(a, a) -> "abcdefghijklmnopqrstuvwxyz"

# %% [markdown]
# __[Link to understand how to sort in Python](https://realpython.com/python-sort/)__

# %%
def longest(a1, a2):
    list1 = list(a1)
    list2 = list(a2)

    list1.extend(list2)
    #In order to avoid repetitions of letters, we turn the list into a set and back into a list
    list1 = list(set(list1))
    sorted_list= sorted(list1)
    sorted_string = "".join(sorted_list)

    return sorted_string

# %%
a = "alexandre"
b = "christophe"

longest(a,b)
# Out:
# 'acdehilnoprstx'

# %% [markdown]
# # Best Practices

# %%
def longest(a1, a2):
    return "".join(sorted(set(a1 + a2)))
