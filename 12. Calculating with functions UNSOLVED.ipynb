# %% [markdown]
# # Calculating with functions - Codewars UNSOLVED TOO HARD
# ***

# %% [markdown]
# This time we want to write calculations using functions and get the results. Let's have a look at some examples:
#
# seven(times(five())) # must return 35 <br>
# four(plus(nine())) # must return 13 <br>
# eight(minus(three())) # must return 5 <br>
# six(divided_by(two())) # must return 3 <br>
#
# Requirements:
#
#     There must be a function for each number from 0 ("zero") to 9 ("nine")
#     There must be a function for each of the following mathematical operations: plus, minus, times, dividedBy (divided_by in Ruby and Python)
#     Each calculation consist of exactly one operation and two numbers
#     The most outer function represents the left operand, the most inner function represents the right operand
#     Division should be integer division. For example, this should return 2, not 2.666666...:
#
# eight(divided_by(three()))
#
# ***

# %%
def zero():
    return int(0)

def one():
    return int(1)

def two():
    return int(2)

def three():
    return int(3)

def four():
    return int(4)

def five():
    return int(5)

def six():
    return int(6)

def seven():
    return int(7)

def eight():
    return int(8)

def nine():
    return int(9)

def plus(x,y):
    return x+y

def minus(x,y):
    return x-y

def times(x,y):
    return x*y

def divided_by(x,y):
    return x//y

# %%
seven(times(five()))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/qv/77qvv71j3gv0ktk3dnzvyzyw0000gn/T/ipykernel_68811/1896760021.py in <module>
# ----> 1 seven(times(five()))
#
# TypeError: times() missing 1 required positional argument: 'y'

# %%
times(seven(five()))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/qv/77qvv71j3gv0ktk3dnzvyzyw0000gn/T/ipykernel_68811/664659171.py in <module>
# ----> 1 times(seven(five()))
#
# TypeError: seven() takes 0 positional arguments but 1 was given
