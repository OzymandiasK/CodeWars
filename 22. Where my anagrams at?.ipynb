# %% [markdown]
# # Where my anagrams at? - Codewars - 5 kyu
# ***

# %% [markdown]
# What is an anagram? Well, two words are anagrams of each other if they both contain the same letters. For example:
#
# 'abba' & 'baab' == true
#
# 'abba' & 'bbaa' == true
#
# 'abba' & 'abbba' == false
#
# 'abba' & 'abca' == false
#
# Write a function that will find all the anagrams of a word from a list. You will be given two inputs a word and an array with words. You should return an array of all the anagrams or an empty array if there are none. For example:
#
# anagrams('abba', ['aabb', 'abcd', 'bbaa', 'dada']) => ['aabb', 'bbaa']
#
# anagrams('racer', ['crazer', 'carer', 'racar', 'caers', 'racer']) => ['carer', 'racer']
#
# anagrams('laser', ['lazing', 'lazy',  'lacer']) => []
#
# ***

# %%
def anagrams(word, words):
    list_anagrams = []
    letters = [letter for letter in sorted(word)]
    #print(letters)
    for potential_anagram in words:
        letters_potential_anagrams = [letter for letter in sorted(potential_anagram)]

        if len(potential_anagram) == len(letters) and letters_potential_anagrams == letters:
            list_anagrams.append(potential_anagram)
            #print('the list of anagrams is:   ' + str(list_anagrams))

    return list_anagrams

# %%
anagrams('abba', ['aabb', 'abcd', 'bbaa', 'dada'])

# %% [markdown]
# # Best Practice

# %%
#author = sandbochs

def anagrams(word, words): return [item for item in words if sorted(item)==sorted(word)]
